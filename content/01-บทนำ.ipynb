# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from sympy import *
from sympy.plotting.plot import List2DSeries, MatplotlibBackend
mpl.font_manager.fontManager.addfont(".matplotlib/LeelawUI.ttf")
mpl.rc_file(".matplotlib/matplotlibrc")

# %%
x, y, t = symbols('x y t')
x = 100*t; y = 100 - Rational(1,2) * 5 * t**2
display(x, y)
# Out:
# 100*t
# 100 - 5*t**2/2

# %%
p = plot_parametric(x,y, (t,0,10),title="ทดสอบ", show=False)
# x_vals = [0, 10]
# y_vals = [0, 80]
# s = List2DSeries(x_vals, y_vals)
be = MatplotlibBackend(p)
be.process_series()
plt = be.plt
plt.arrow(0,100,25,25, length_includes_head=True, head_width=10)
# plt.annotate("ความเร", xy=(0, 10.05))
# ax.arrow(fig, 0,0,1,1, length_includes_head=True, head_width=0.02, head_length=0.04)

# %%
plt.arrow(0,0,1,1, length_includes_head=True, head_width=0.02, head_length=0.04)

# plt.arrow(1,1,0,1)

# %%
from sympy.plotting.plot import List2DSeries, Plot

Plot(s).show()
